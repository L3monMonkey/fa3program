# %% [markdown]
# <a href="https://colab.research.google.com/github/L3monMonkey/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str(input("Write your name: "))
age = int(input("Your age: "))
varc = str(input("Your course: "))

print("name:", name)
print("age:", age)
print("current couse:", varc)
# Out:
# Write your name: Lorendino
# Your age: 12030
# Your course: CS 1
# name: Lorendino
# age: 12030
# current couse CS 1

# %%
score = int(input("input score:"))
if score <= 75:
  print("Failed")
else:
  print("Passed")
print("your score:", score)

# %%
name = str(input("Name:"))
score = int(input(("Grade:")))

if score >= 90:
  print("A")
elif 80 <= score <= 89:
  print("B")
elif 70 <= score <= 79:
  print("C")
elif 60 <= score <= 69:
  print("D")
else:
  print("F")
# Out:
# Name:mawmaw
# Grade:10
# F
